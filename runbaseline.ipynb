# %%
./naive_baseline.py --scenario="nic" --sub_dir="nic"

# %%
# !jupyter kernelspec list

# %%
# !ls -alt /usr/local/share/jupyter/kernels/python3-azureml

# %%
# !python -V

# %%
from datetime import datetime
startTime = datetime.now()

scenarios = ['ni', 'multi-task-nc', 'nic']

for s in scenarios:
    # !python ./naive_baseline.py --scenario="{s}" --sub_dir="{s}"
    print('time for {}: {}'.format(s, datetime.now() - startTime))
    
print('total time: {}'.format(datetime.now() - startTime))
# Out:
# Namespace(batch_size=32, classifier='ResNet18', cuda=True, device='cuda:0', epochs=1, input_size=[3, 128, 128], lr=0.01, n_classes=50, preload_data=True, replay_examples=0, scenario='ni', sub_dir='ni')
#
# Loading data...
# Loading paths...
# Loading LUP...
# Loading labels...
# preparing CL benchmark...
# Recovering validation set...
# ----------- batch 0 -------------
# x shape: (14991, 128, 128, 3), y shape: (14991,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.120907, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000363, running train acc: 0.589
# ==>>> it: 200, avg. loss: 0.000035, running train acc: 0.758
# ==>>> it: 300, avg. loss: 0.000020, running train acc: 0.829
# ==>>> it: 400, avg. loss: 0.000013, running train acc: 0.868
# ------------------------------------------
# Avg. acc: [0.42152067585593594]
# ------------------------------------------
# ----------- batch 1 -------------
# x shape: (14995, 128, 128, 3), y shape: (14995,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.035360, running train acc: 0.719
# ==>>> it: 100, avg. loss: 0.000081, running train acc: 0.899
# ==>>> it: 200, avg. loss: 0.000014, running train acc: 0.937
# ==>>> it: 300, avg. loss: 0.000010, running train acc: 0.953
# ==>>> it: 400, avg. loss: 0.000008, running train acc: 0.964
# ------------------------------------------
# Avg. acc: [0.43663850600266785]
# ------------------------------------------
# ----------- batch 2 -------------
# x shape: (14986, 128, 128, 3), y shape: (14986,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.033193, running train acc: 0.781
# ==>>> it: 100, avg. loss: 0.000016, running train acc: 0.907
# ==>>> it: 200, avg. loss: 0.000007, running train acc: 0.942
# ==>>> it: 300, avg. loss: 0.000004, running train acc: 0.958
# ==>>> it: 400, avg. loss: 0.000003, running train acc: 0.968
# ------------------------------------------
# Avg. acc: [0.6647398843930635]
# ------------------------------------------
# ----------- batch 3 -------------
# x shape: (14994, 128, 128, 3), y shape: (14994,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.026031, running train acc: 0.719
# ==>>> it: 100, avg. loss: 0.000044, running train acc: 0.910
# ==>>> it: 200, avg. loss: 0.000010, running train acc: 0.942
# ==>>> it: 300, avg. loss: 0.000003, running train acc: 0.957
# ==>>> it: 400, avg. loss: 0.000001, running train acc: 0.966
# ------------------------------------------
# Avg. acc: [0.5753668297020899]
# ------------------------------------------
# ----------- batch 4 -------------
# x shape: (14989, 128, 128, 3), y shape: (14989,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.020485, running train acc: 0.812
# ==>>> it: 100, avg. loss: 0.000009, running train acc: 0.939
# ==>>> it: 200, avg. loss: 0.000008, running train acc: 0.958
# ==>>> it: 300, avg. loss: 0.000002, running train acc: 0.969
# ==>>> it: 400, avg. loss: 0.000001, running train acc: 0.975
# ------------------------------------------
# Avg. acc: [0.5904846598488217]
# ------------------------------------------
# ----------- batch 5 -------------
# x shape: (14989, 128, 128, 3), y shape: (14989,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.022794, running train acc: 0.750
# ==>>> it: 100, avg. loss: 0.000036, running train acc: 0.907
# ==>>> it: 200, avg. loss: 0.000009, running train acc: 0.941
# ==>>> it: 300, avg. loss: 0.000002, running train acc: 0.957
# ==>>> it: 400, avg. loss: 0.000003, running train acc: 0.966
# ------------------------------------------
# Avg. acc: [0.5602489995553579]
# ------------------------------------------
# ----------- batch 6 -------------
# x shape: (14966, 128, 128, 3), y shape: (14966,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.016259, running train acc: 0.875
# ==>>> it: 100, avg. loss: 0.000015, running train acc: 0.951
# ==>>> it: 200, avg. loss: 0.000004, running train acc: 0.968
# ==>>> it: 300, avg. loss: 0.000009, running train acc: 0.976
# ==>>> it: 400, avg. loss: 0.000001, running train acc: 0.981
# ------------------------------------------
# Avg. acc: [0.5838150289017341]
# ------------------------------------------
# ----------- batch 7 -------------
# x shape: (14984, 128, 128, 3), y shape: (14984,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.011152, running train acc: 0.875
# ==>>> it: 100, avg. loss: 0.000033, running train acc: 0.928
# ==>>> it: 200, avg. loss: 0.000021, running train acc: 0.950
# ==>>> it: 300, avg. loss: 0.000003, running train acc: 0.962
# ==>>> it: 400, avg. loss: 0.000003, running train acc: 0.969
# ------------------------------------------
# Avg. acc: [0.6980880391285016]
# ------------------------------------------
# Training Time: 9.740340336163838m
# Final inference on test set...
# Experiment completed.
# time for ni: 0:11:12.856481
# Namespace(batch_size=32, classifier='ResNet18', cuda=True, device='cuda:0', epochs=1, input_size=[3, 128, 128], lr=0.01, n_classes=50, preload_data=True, replay_examples=0, scenario='multi-task-nc', sub_dir='multi-task-nc')
#
# Loading data...
# Loading paths...
# Loading LUP...
# Loading labels...
# preparing CL benchmark...
# Recovering validation set...
# ----------- batch 0 -------------
# x shape: (23980, 128, 128, 3), y shape: (23980,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.137532, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000059, running train acc: 0.842
# ==>>> it: 200, avg. loss: 0.000010, running train acc: 0.913
# ==>>> it: 300, avg. loss: 0.000008, running train acc: 0.940
# ==>>> it: 400, avg. loss: 0.000003, running train acc: 0.954
# ==>>> it: 500, avg. loss: 0.000002, running train acc: 0.962
# ==>>> it: 600, avg. loss: 0.000000, running train acc: 0.968
# ==>>> it: 700, avg. loss: 0.000000, running train acc: 0.972
# ------------------------------------------
# Avg. acc: [0.10444444444444444]
# ------------------------------------------
# ----------- batch 1 -------------
# x shape: (11993, 128, 128, 3), y shape: (11993,)
# Task Label:  1
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000009, running train acc: 0.959
# ==>>> it: 200, avg. loss: 0.000002, running train acc: 0.978
# ==>>> it: 300, avg. loss: 0.000002, running train acc: 0.984
# ------------------------------------------
# Avg. acc: [0.2106172839506173]
# ------------------------------------------
# ----------- batch 2 -------------
# x shape: (11990, 128, 128, 3), y shape: (11990,)
# Task Label:  2
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000015, running train acc: 0.953
# ==>>> it: 200, avg. loss: 0.000001, running train acc: 0.973
# ==>>> it: 300, avg. loss: 0.000006, running train acc: 0.981
# ------------------------------------------
# Avg. acc: [0.31308641975308643]
# ------------------------------------------
# ----------- batch 3 -------------
# x shape: (11993, 128, 128, 3), y shape: (11993,)
# Task Label:  3
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000018, running train acc: 0.963
# ==>>> it: 200, avg. loss: 0.000002, running train acc: 0.979
# ==>>> it: 300, avg. loss: 0.000001, running train acc: 0.985
# ------------------------------------------
# Avg. acc: [0.4138271604938272]
# ------------------------------------------
# ----------- batch 4 -------------
# x shape: (11989, 128, 128, 3), y shape: (11989,)
# Task Label:  4
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000016, running train acc: 0.934
# ==>>> it: 200, avg. loss: 0.000004, running train acc: 0.963
# ==>>> it: 300, avg. loss: 0.000002, running train acc: 0.974
# ------------------------------------------
# Avg. acc: [0.519753086419753]
# ------------------------------------------
# ----------- batch 5 -------------
# x shape: (11979, 128, 128, 3), y shape: (11979,)
# Task Label:  5
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000030, running train acc: 0.954
# ==>>> it: 200, avg. loss: 0.000004, running train acc: 0.970
# ==>>> it: 300, avg. loss: 0.000007, running train acc: 0.978
# ------------------------------------------
# Avg. acc: [0.6237037037037036]
# ------------------------------------------
# ----------- batch 6 -------------
# x shape: (11990, 128, 128, 3), y shape: (11990,)
# Task Label:  6
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000020, running train acc: 0.967
# ==>>> it: 200, avg. loss: 0.000002, running train acc: 0.981
# ==>>> it: 300, avg. loss: 0.000001, running train acc: 0.987
# ------------------------------------------
# Avg. acc: [0.7355555555555555]
# ------------------------------------------
# ----------- batch 7 -------------
# x shape: (11987, 128, 128, 3), y shape: (11987,)
# Task Label:  7
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000009, running train acc: 0.959
# ==>>> it: 200, avg. loss: 0.000009, running train acc: 0.979
# ==>>> it: 300, avg. loss: 0.000001, running train acc: 0.986
# ------------------------------------------
# Avg. acc: [0.8192592592592592]
# ------------------------------------------
# ----------- batch 8 -------------
# x shape: (11993, 128, 128, 3), y shape: (11993,)
# Task Label:  8
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122251, running train acc: 0.000
# ==>>> it: 100, avg. loss: 0.000018, running train acc: 0.967
# ==>>> it: 200, avg. loss: 0.000019, running train acc: 0.981
# ==>>> it: 300, avg. loss: 0.000000, running train acc: 0.987
# ------------------------------------------
# Avg. acc: [0.9256790123456791]
# ------------------------------------------
# Training Time: 9.82026102145513m
# Final inference on test set...
# Experiment completed.
# time for multi-task-nc: 0:22:28.611228
# Namespace(batch_size=32, classifier='ResNet18', cuda=True, device='cuda:0', epochs=1, input_size=[3, 128, 128], lr=0.01, n_classes=50, preload_data=True, replay_examples=0, scenario='nic', sub_dir='nic')
#
# Loading data...
# Loading paths...
# Loading LUP...
# Loading labels...
# preparing CL benchmark...
# Recovering validation set...
# ----------- batch 0 -------------
# x shape: (2999, 128, 128, 3), y shape: (2999,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.128345, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.11694086260560249]
# ------------------------------------------
# ----------- batch 1 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.095939, running train acc: 0.125
# ------------------------------------------
# Avg. acc: [0.02401067140951534]
# ------------------------------------------
# ----------- batch 2 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000907, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.02267674522009782]
# ------------------------------------------
# ----------- batch 3 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000732, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.021787461093819474]
# ------------------------------------------
# ----------- batch 4 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.255087, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.029791018230324588]
# ------------------------------------------
# ----------- batch 5 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000897, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 6 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.253784, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020898176967541128]
# ------------------------------------------
# ----------- batch 7 -------------
# x shape: (295, 128, 128, 3), y shape: (295,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.237710, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.030680302356602934]
# ------------------------------------------
# ----------- batch 8 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.240939, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.02401067140951534]
# ------------------------------------------
# ----------- batch 9 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.239709, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.022232103156958647]
# ------------------------------------------
# ----------- batch 10 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.217961, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 11 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.222617, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 12 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.253450, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.0213428190306803]
# ------------------------------------------
# ----------- batch 13 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.210787, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 14 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.217285, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 15 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.193202, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 16 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.218954, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 17 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.342823, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 18 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.253260, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 19 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000771, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 20 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.281642, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.03468208092485549]
# ------------------------------------------
# ----------- batch 21 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.200069, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.025344597598932858]
# ------------------------------------------
# ----------- batch 22 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.251743, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 23 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.226177, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 24 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.253303, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 25 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.213493, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 26 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.244688, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020898176967541128]
# ------------------------------------------
# ----------- batch 27 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.214884, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 28 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.329698, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 29 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000823, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 30 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.239304, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 31 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.237168, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 32 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.211247, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 33 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.199821, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020898176967541128]
# ------------------------------------------
# ----------- batch 34 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.232192, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.021787461093819474]
# ------------------------------------------
# ----------- batch 35 -------------
# x shape: (297, 128, 128, 3), y shape: (297,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.260209, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 36 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.001066, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 37 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.235481, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 38 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.198218, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 39 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.348309, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.021787461093819474]
# ------------------------------------------
# ----------- batch 40 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.237053, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 41 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.279014, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 42 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.254072, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 43 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.205320, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 44 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.220057, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 45 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.257050, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.021787461093819474]
# ------------------------------------------
# ----------- batch 46 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.216090, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 47 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.239153, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 48 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.246217, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 49 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.191088, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 50 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.245978, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 51 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.259121, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020453534904401955]
# ------------------------------------------
# ----------- batch 52 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.278138, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 53 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000901, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 54 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.243599, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 55 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000684, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 56 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.354252, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 57 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.316409, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 58 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000650, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 59 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000399, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 60 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.273747, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 61 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.322167, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 62 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.244347, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 63 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.222175, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 64 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.236537, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 65 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.323620, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 66 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.299532, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 67 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.247136, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 68 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.249219, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 69 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.252424, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 70 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.327172, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 71 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.191165, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 72 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.254229, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 73 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.249952, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 74 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.255646, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 75 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.246573, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 76 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.249604, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 77 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.251363, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 78 -------------
# x shape: (296, 128, 128, 3), y shape: (296,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.307796, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 79 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.244826, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 80 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.251506, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 81 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.243848, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 82 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.255950, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 83 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.257468, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 84 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.227180, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 85 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.225873, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 86 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000714, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 87 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.263040, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 88 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.287648, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 89 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.199311, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 90 -------------
# x shape: (297, 128, 128, 3), y shape: (297,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000652, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 91 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.337771, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 92 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.266221, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 93 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.255147, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 94 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.278242, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 95 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.261977, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 96 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.266319, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 97 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.196598, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 98 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.240161, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 99 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.199591, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 100 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.253181, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 101 -------------
# x shape: (297, 128, 128, 3), y shape: (297,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.175646, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 102 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000838, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 103 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.349755, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 104 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.173798, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 105 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.256655, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 106 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.275535, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 107 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.184691, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 108 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.276681, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 109 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.219232, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 110 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.254532, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 111 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.252598, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 112 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000821, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 113 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.218195, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 114 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.259725, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 115 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.290448, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 116 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.203549, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 117 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.230672, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 118 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.331103, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 119 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.222280, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 120 -------------
# x shape: (293, 128, 128, 3), y shape: (293,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000854, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 121 -------------
# x shape: (298, 128, 128, 3), y shape: (298,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.195343, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 122 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.251709, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 123 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.259274, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 124 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.172984, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 125 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.268794, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 126 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.175122, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 127 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.153598, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 128 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.226221, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 129 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.000764, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 130 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.269265, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 131 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ...
# training ep:  0
# ==>>> it: 0, avg. loss: 0.160844, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 337 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.184211, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 338 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.272109, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 339 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.207867, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 340 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.311947, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 341 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.174704, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 342 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.243844, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 343 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.245648, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 344 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.158719, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 345 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.181109, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 346 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.186593, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 347 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.235128, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 348 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.172447, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 349 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.146096, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 350 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.228355, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 351 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.151290, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 352 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.229094, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 353 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.156983, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 354 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.266449, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 355 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.133464, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 356 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.159339, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 357 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.212398, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 358 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.001591, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 359 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.198070, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 360 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.236077, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 361 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.196842, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 362 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.178854, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 363 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.182336, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 364 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.274992, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 365 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.196297, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 366 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.121643, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 367 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.129474, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 368 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.213968, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 369 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.214577, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 370 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.170483, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 371 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.275813, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 372 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.214873, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 373 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.160784, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 374 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.269853, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 375 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.108820, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 376 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.290935, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 377 -------------
# x shape: (299, 128, 128, 3), y shape: (299,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.202760, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 378 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.211374, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 379 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.190785, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 380 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.139333, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 381 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.247646, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 382 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.122722, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 383 -------------
# x shape: (297, 128, 128, 3), y shape: (297,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.001056, running train acc: 1.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 384 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.200884, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 385 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.163869, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 386 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.285819, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 387 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.189549, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 388 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.152156, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 389 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.236421, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# ----------- batch 390 -------------
# x shape: (300, 128, 128, 3), y shape: (300,)
# Task Label:  0
# training ep:  0
# ==>>> it: 0, avg. loss: 0.184746, running train acc: 0.000
# ------------------------------------------
# Avg. acc: [0.020008892841262782]
# ------------------------------------------
# Training Time: 27.52538637717565m
# Final inference on test set...
# Experiment completed.
# time for nic: 0:51:26.043531
# total time: 0:51:26.043998

# %%
# original
